# %%
import pandas as pd

# %% [markdown]
# **Import the data frame**

# %%
#Read CSV file into data frame named 'routes_df'
df_1000 = pd.read_csv\
('/Users/Dali/Documents/DSI-7/projects/project_4/problem3/Project4/Dali/csv/3.Google_directions_api_0-1k.csv')

# %%
df_1000.shape
# Out:
# (1000, 16)

# %%
df_1000.head(1)
# Out:
#    Unnamed: 0  osmid_start    x_start    y_start  start_zone  osmid_end  \
# 0           0     66450694 -71.090072  42.436659           1   66449255
#
#        x_end     y_end  end_zone  Time             Time_adj distance duration  \
# 0 -71.092265  42.41105         2  8:30  May 31 2019  8:30AM   2.8 mi   8 mins
#
#   duration_in_traffic                                        coordinates  \
# 0              9 mins  {0: {'lat': 42.4373659, 'lng': -71.08992169999...
#
#                                           directions
# 0  {0: 'Head north on Palmer St toward Park Ave',...

# %%
df_2000 = pd.read_csv\
('/Users/Dali/Documents/DSI-7/projects/project_4/problem3/Project4/Dali/csv/4.Google_directions_api_1-2k.csv')

# %%
df_2000.head(1)
# Out:
#    Unnamed: 0  osmid_start   x_start    y_start  start_zone  osmid_end  \
# 0        1000     66434546 -71.09189  42.428293           1   66459547
#
#        x_end      y_end  end_zone   Time             Time_adj distance  \
# 0 -71.121782  42.411549         0  15:30  May 31 2019  3:30PM   2.8 mi
#
#   duration duration_in_traffic  \
# 0  10 mins             11 mins
#
#                                          coordinates  \
# 0  {0: {'lat': 42.4282441, 'lng': -71.0921821}, 1...
#
#                                           directions
# 0  {0: 'Head west on Lund Rd toward Cedar Rd N', ...

# %%
df_3000 = pd.read_csv\
('/Users/Dali/Documents/DSI-7/projects/project_4/problem3/Project4/Dali/csv/5.Google_directions_api_2-3k.csv')

# %%
df_3000.head(1)
# Out:
#    Unnamed: 0  osmid_start    x_start    y_start  start_zone  osmid_end  \
# 0        2000     66421825 -71.079618  42.410299           2   66452585
#
#        x_end      y_end  end_zone   Time             Time_adj distance  \
# 0 -71.093543  42.436255         1  17:30  May 31 2019  5:30PM   2.4 mi
#
#   duration duration_in_traffic  \
# 0   9 mins             11 mins
#
#                                          coordinates  \
# 0  {0: {'lat': 42.4131982, 'lng': -71.07927699999...
#
#                                           directions
# 0  {0: 'Head north on Middlesex Ave toward 2nd St...

# %%
df_4000 = pd.read_csv\
('/Users/Dali/Documents/DSI-7/projects/project_4/problem3/Project4/Dali/csv/6.Google_directions_api_3-4k.csv')

# %%
df_4000.head(1)
# Out:
#    Unnamed: 0  osmid_start    x_start    y_start  start_zone  osmid_end  \
# 0        3000    940961064 -71.094616  42.444456           1   66481352
#
#        x_end      y_end  end_zone  Time             Time_adj distance  \
# 0 -71.079786  42.403226         2  8:30  May 31 2019  8:30AM   3.4 mi
#
#   duration duration_in_traffic  \
# 0  11 mins             13 mins
#
#                                          coordinates  \
# 0  {0: {'lat': 42.4425761, 'lng': -71.0941721}, 1...
#
#                                           directions
# 0  {0: 'Head south on Woodland Rd', 1: 'At the tr...

# %%
df_5000 = pd.read_csv\
('/Users/Dali/Documents/DSI-7/projects/project_4/problem3/Project4/Dali/csv/8.Google_directions_api_4-5k.csv')

# %%
df_5000.head(1)
# Out:
#    Unnamed: 0  osmid_start    x_start    y_start  start_zone  osmid_end  \
# 0        4000     66425640 -71.080642  42.406521           2   66443549
#
#        x_end      y_end  end_zone   Time             Time_adj distance  \
# 0 -71.122337  42.410717         0  15:30  May 31 2019  3:30PM   3.2 mi
#
#   duration duration_in_traffic  \
# 0  10 mins             11 mins
#
#                                          coordinates  \
# 0  {0: {'lat': 42.4065916, 'lng': -71.0809605}, 1...
#
#                                           directions
# 0  {0: 'Head west on 8th St toward Middlesex AveR...

# %%
df_6000 = pd.read_csv\
('/Users/Dali/Documents/DSI-7/projects/project_4/problem3/Project4/Dali/csv/9.Google_directions_api_5-6k.csv')

# %%
df_6000.head(1)
# Out:
#    Unnamed: 0  osmid_start    x_start    y_start  start_zone  osmid_end  \
# 0        5000     66422683 -71.127038  42.410869           0   66422566
#
#        x_end      y_end  end_zone   Time             Time_adj distance  \
# 0 -71.090547  42.433056         1  17:30  May 31 2019  5:30PM   5.3 mi
#
#   duration duration_in_traffic  \
# 0  13 mins             17 mins
#
#                                          coordinates  \
# 0  {0: {'lat': 42.4102953, 'lng': -71.1254834}, 1...
#
#                                           directions
# 0  {0: 'Head southeast on Osgood St toward Adams ...

# %%
df_all6 = pd.concat([df_1000, df_2000, df_3000, df_4000, df_5000, df_6000], axis=0, join='outer', join_axes=None, ignore_index=False,
          keys=None, levels=None, names=None, verify_integrity=False,
          copy=True)

# %%
df_all6.shape
# Out:
# (6000, 16)

# %%
df_all6.tail()
# Out:
#      Unnamed: 0  osmid_start    x_start    y_start  start_zone   osmid_end  \
# 995        5995     66427664 -71.120235  42.410581           0    66452543
# 996        5996     66427664 -71.120235  42.410581           0    66452543
# 997        5997     66427146 -71.081243  42.405841           2  2295021981
# 998        5998     66427146 -71.081243  42.405841           2  2295021981
# 999        5999     66427146 -71.081243  42.405841           2  2295021981
#
#          x_end      y_end  end_zone   Time             Time_adj distance  \
# 995 -71.095525  42.400850         2  15:30  May 31 2019  3:30PM   1.9 mi
# 996 -71.095525  42.400850         2  17:30  May 31 2019  5:30PM   1.9 mi
# 997 -71.121101  42.409832         0   8:30  May 31 2019  8:30AM   3.3 mi
# 998 -71.121101  42.409832         0  15:30  May 31 2019  3:30PM   3.3 mi
# 999 -71.121101  42.409832         0  17:30  May 31 2019  5:30PM   3.3 mi
#
#     duration duration_in_traffic  \
# 995   7 mins              8 mins
# ...

# %%
df_all6 = df_all6.loc[:, ~df_all6.columns.str.contains('^Unnamed')]
df_all6.head(1)
# Out:
#    osmid_start    x_start    y_start  start_zone  osmid_end      x_end  \
# 0     66450694 -71.090072  42.436659           1   66449255 -71.092265
#
#       y_end  end_zone  Time             Time_adj distance duration  \
# 0  42.41105         2  8:30  May 31 2019  8:30AM   2.8 mi   8 mins
#
#   duration_in_traffic                                        coordinates  \
# 0              9 mins  {0: {'lat': 42.4373659, 'lng': -71.08992169999...
#
#                                           directions
# 0  {0: 'Head north on Palmer St toward Park Ave',...

# %%
df_all6.to_csv('/Users/Dali/Documents/DSI-7/projects/project_4/problem3/Project4/Dali/csv/10.Google_directions_api_all6k.csv')
